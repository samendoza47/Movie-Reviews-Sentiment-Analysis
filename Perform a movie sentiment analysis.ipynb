# %% [markdown]
# 1. Choose a Netflix movie of interest.
#
# 2. Download the comments / find a movie comment file.
#
# 3. Import libraries for sentiment classification of the comments of your favorite movie ( positive/ negative / neutral ).
#
# 4. Submit your compiled code.

# %%
import os
import nltk
import pandas as pd
from nltk.corpus import movie_reviews

import warnings
warnings.filterwarnings('ignore')

# %%
#nltk.download('movie_reviews')

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/samendoza47/hello-world/master/IMDBDataset.csv?token=GHSAT0AAAAAABVWQ5YXERT77KRNO6IEJJZ2YVP4M2A')

import numpy as np


url = 'https://drive.google.com/file/d/1kvoXXSuCz3LfyX9SpBlsZs-5nDO5Eypz/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)

df.head()


df_reviews = df[df.index < 3000]
df_reviews.head(3)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive

# %%
# Rename Values
df_reviews['sentiment'] = df_reviews['sentiment'].replace(['positive', 'negative'], ['pos', 'neg'])
df_reviews.head(3)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...       pos
# 1  A wonderful little production. <br /><br />The...       pos
# 2  I thought this was a wonderful way to spend ti...       pos

# %%
#movie_reviews.words()
df_reviews['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %%
import string

text = " ".join(df_reviews['review'])
text_filtered = text.translate(str.maketrans('','',string.punctuation))

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords

stopwords = stopwords.words('english')
tokens = word_tokenize(text_filtered)
word_filtered = [w.lower() for w in tokens if w not in stopwords]

# %%
counter_dict = nltk.FreqDist(word_filtered)
print(counter_dict.most_common(15))
# Out:
# [('i', 8576), ('br', 6941), ('the', 5429), ('movie', 5057), ('film', 4500), ('one', 2927), ('like', 2264), ('this', 1888), ('good', 1725), ('even', 1496), ('would', 1476), ('it', 1450), ('see', 1415), ('story', 1353), ('time', 1334)]

# %%
docs = []
for i in range(len(df_reviews)):
    token_word = word_tokenize(df_reviews['review'][i])
    docs += [(token_word, df_reviews['sentiment'][i])]

# %%
# Create a list containing 3000 most frequent words
word_features = [w[0] for w in counter_dict.most_common(3000)]

# %%
def search_features(doc):
    words = set(doc)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features

# %%
search_features(docs[0][0])
# Out:
# {'i': False,
#  'br': True,
#  'the': True,
#  'movie': False,
#  'film': False,
#  'one': False,
#  'like': False,
#  'this': True,
#  'good': False,
#  'even': False,
#  'would': True,
#  'it': True,
#  'see': False,
#  'story': False,
#  'time': False,
#  'really': False,
#  'much': False,
#  'well': True,
#  'get': True,
#  'bad': False,
#  'also': False,
#  'first': True,
#  'people': False,
#  'great': False,
#  'dont': False,
#  'movies': False,
#  'way': False,
#  'made': False,
#  'films': False,
#  'make': False,
#  'characters': False,
#  'could': True,
#  'and': True,
#  'think': False,
#  'watch': False,
#  'but': True,
#  'many': True,
#  'its': True,
#  'little': False,
#  'plot': False,
#  'never': True,
#  'two': False,
#  'character': False,
#  'seen': False,
#  'a': True,
#  'know': False,
#  'acting': False,
#  'in': True,
#  'love': False,
#  'life': False,
#  'if': True,
#  'best': False,
#  'ever': True,
#  'show': True,
#  'better': False,
#  'say': True,
#  'still': False,
#  'scene': False,
#  'man': False,
#  'there': False,
#  'scenes': True,
#  'go': False,
#  'something': False,
#  'end': False,
#  'real': False,
#  'im': False,
#  'watching': True,
#  'doesnt': False,
#  'back': False,
#  'actors': False,
#  'funny': False,
#  'new': False,
#  'he': False,
#  'thing': True,
#  'though': False,
#  'years': False,
#  'didnt': False,
#  'going': False,
#  'find': False,
#  'look': False,
#  'work': False,
#  'makes': False,
#  'actually': False,
#  'another': False,
#  'want': False,
#  'us': False,
#  'lot': False,
#  'part': False,
#  'old': False,
#  'every': False,
#  'nothing': False,
#  'cant': False,
#  'director': False,
#  'got': True,
#  'quite': False,
#  'pretty': True,
#  'things': False,
#  'around': True,
#  'enough': False,
#  'young': False,
#  'however': False,
#  'world': False,
#  'cast': False,
#  'big': False,
#  'must': False,
#  'thats': True,
#  'seems': False,
#  'as': True,
#  'may': True,
#  'long': False,
#  'fact': True,
#  'give': False,
#  'come': False,
#  'take': False,
#  'gets': False,
#  'without': False,
#  'least': False,
#  'whole': False,
#  'almost': False,
#  'horror': False,
#  'always': False,
#  'ive': False,
#  'saw': True,
#  'thought': False,
#  'original': False,
#  'might': False,
#  'you': True,
#  'since': False,
#  'isnt': False,
#  'right': True,
#  'anything': False,
#  'interesting': False,
#  'script': False,
#  'times': False,
#  'feel': False,
#  'comedy': False,
#  'probably': False,
#  'role': False,
#  'what': True,
#  'done': False,
#  'point': False,
#  'theres': False,
#  'family': False,
#  'minutes': False,
#  'yet': False,
#  'anyone': False,
#  'played': False,
#  'performance': False,
#  'they': False,
#  'although': False,
#  'bit': False,
#  'series': False,
#  'far': True,
#  'action': False,
#  'last': False,
#  'music': False,
#  'away': True,
#  'comes': False,
#  'rather': False,
#  'guy': False,
#  'so': True,
#  'not': True,
#  'tv': False,
#  'sure': False,
#  'kind': False,
#  'making': False,
#  'woman': False,
#  'everything': False,
#  'three': False,
#  'hard': False,
#  'worst': False,
#  'girl': False,
#  'fun': False,
#  'book': False,
#  'takes': False,
#  'she': False,
#  'hes': False,
#  'when': False,
#  'true': False,
#  'course': False,
#  'watched': True,
#  'especially': False,
#  'believe': False,
#  'found': False,
#  'goes': True,
#  'money': False,
#  'american': False,
#  'day': False,
#  'wasnt': False,
#  'different': False,
#  'main': True,
#  'shows': True,
#  'worth': False,
#  'trying': False,
#  'audience': False,
#  'idea': False,
#  'looks': False,
#  'screen': False,
#  'effects': False,
#  'john': False,
#  'beautiful': False,
#  'dvd': False,
#  'put': False,
#  'ending': False,
#  'everyone': False,
#  'maybe': False,
#  'simply': False,
#  'set': True,
#  'my': False,
#  'all': True,
#  'read': False,
#  'reason': False,
#  'seem': False,
#  'left': False,
#  'looking': False,
#  'excellent': False,
#  '10': False,
#  'place': False,
#  'night': False,
#  'together': False,
#  'completely': False,
#  'sense': False,
#  'plays': False,
#  'war': False,
#  'actor': False,
#  'for': True,
#  'special': False,
#  'instead': False,
#  'men': False,
#  'help': False,
#  'play': False,
#  'we': False,
#  'someone': False,
#  'job': False,
#  'short': False,
#  'nice': False,
#  'poor': False,
#  'seeing': False,
#  'fan': False,
#  'given': True,
#  'no': True,
#  'tell': False,
#  '2': False,
#  'along': False,
#  'shot': False,
#  'home': True,
#  'star': False,
#  'mind': False,
#  'said': False,
#  'use': True,
#  'used': False,
#  'line': False,
#  'else': False,
#  'second': False,
#  'performances': False,
#  'later': False,
#  'need': False,
#  'youre': False,
#  'father': False,
#  'version': False,
#  'house': False,
#  'rest': False,
#  'kids': False,
#  'high': True,
#  'wonderful': False,
#  'piece': False,
#  'black': False,
#  'recommend': False,
#  'try': False,
#  'human': False,
#  'year': False,
#  'less': False,
#  'absolutely': False,
#  'next': False,
#  'stupid': False,
#  'hollywood': False,
#  'dead': False,
#  'enjoy': False,
#  'classic': True,
#  'that': True,
#  'playing': False,
#  'either': False,
#  'mean': False,
#  'boring': False,
#  'remember': False,
#  'half': False,
#  'at': False,
#  'definitely': False,
#  'let': False,
#  'of': True,
#  'wife': False,
#  'production': False,
#  'title': False,
#  'terrible': False,
#  'women': False,
#  'small': False,
#  'understand': False,
#  'truly': False,
#  'awful': False,
#  'based': False,
#  'came': False,
#  'video': False,
#  'others': False,
#  'couple': False,
#  'death': True,
#  'totally': False,
#  'keep': False,
#  'mother': False,
#  'friends': False,
#  'loved': False,
#  'moments': False,
#  'case': False,
#  'game': False,
#  'fans': False,
#  'couldnt': False,
#  'lost': False,
#  'youll': False,
#  'stars': False,
#  'wrong': False,
#  'finally': False,
#  'evil': False,
#  'after': True,
#  'several': False,
#  'camera': False,
#  'start': False,
#  'school': False,
#  'top': False,
#  'sex': True,
#  'worse': False,
#  'humor': False,
#  'getting': False,
#  'often': False,
#  'name': False,
#  'perfect': False,
#  'face': True,
#  'person': False,
#  'liked': False,
#  'shes': False,
#  'budget': False,
#  'already': False,
#  'full': False,
#  'girls': False,
#  'yes': False,
#  'to': True,
#  'friend': False,
#  'dialogue': False,
#  'episode': True,
#  '3': False,
#  'despite': False,
#  'lines': False,
#  'wants': False,
#  'overall': False,
#  'written': False,
#  'while': False,
#  'some': False,
#  'beginning': False,
#  'gives': False,
#  'entire': False,
#  'mr': False,
#  'direction': False,
#  'waste': False,
#  'sort': False,
#  'becomes': False,
#  'favorite': False,
#  'perhaps': False,
#  'id': False,
#  'felt': False,
#  'dark': False,
#  'supposed': False,
#  'certainly': False,
#  'called': True,
#  'laugh': False,
#  'turn': False,
#  'picture': False,
#  'become': True,
#  'drama': False,
#  'early': False,
#  'town': False,
#  'seemed': False,
#  'children': False,
#  'then': False,
#  'quality': False,
#  'hope': False,
#  'guys': False,
#  'wanted': False,
#  'matter': False,
#  'sound': False,
#  'final': False,
#  'head': False,
#  'oh': False,
#  '\x96': False,
#  'cinema': False,
#  'throughout': False,
#  'soon': False,
#  'gave': False,
#  'why': False,
#  'able': False,
#  'his': False,
#  'parts': False,
#  'history': False,
#  'stuff': False,
#  'entertaining': False,
#  'problem': False,
#  'care': False,
#  'fine': False,
#  'now': False,
#  'number': False,
#  'lack': True,
#  'eyes': False,
#  'days': False,
#  'style': False,
#  'lives': False,
#  'live': False,
#  'past': False,
#  'went': False,
#  'viewer': False,
#  'extremely': False,
#  'white': False,
#  'theyre': False,
#  'ill': False,
#  'brilliant': False,
#  'type': False,
#  'wont': False,
#  'writing': False,
#  'enjoyed': False,
#  'murder': False,
#  'low': False,
#  'behind': False,
#  'ones': False,
#  'god': False,
#  'is': True,
#  'actress': False,
#  'robert': False,
#  'itbr': False,
#  'unfortunately': False,
#  'art': False,
#  'coming': False,
#  'save': False,
#  'attempt': False,
#  'lead': False,
#  'violence': True,
#  'just': True,
#  'expect': False,
#  'experience': True,
#  'boy': False,
#  'turns': False,
#  'tries': False,
#  'hell': False,
#  'thinking': False,
#  'leave': False,
#  'amazing': False,
#  'police': False,
#  'obviously': False,
#  'son': False,
#  'word': True,
#  'ridiculous': False,
#  'horrible': False,
#  'example': False,
#  'group': False,
#  'city': False,
#  'works': False,
#  'told': False,
#  'sometimes': False,
#  'michael': False,
#  'slow': False,
#  'happens': False,
#  '1': True,
#  'david': False,
#  'decent': False,
#  'involved': False,
#  'car': False,
#  'heart': False,
#  'wouldnt': False,
#  'stop': False,
#  'happen': False,
#  'television': False,
#  'shown': False,
#  'complete': False,
#  'song': False,
#  'except': False,
#  'known': False,
#  'with': True,
#  'took': False,
#  'ago': False,
#  'guess': False,
#  'age': False,
#  'act': False,
#  'disappointed': False,
#  'chance': False,
#  'heard': False,
#  'particularly': False,
#  'looked': False,
#  'close': False,
#  'highly': False,
#  'english': False,
#  'reality': False,
#  'upon': False,
#  'killed': False,
#  'kill': True,
#  'huge': False,
#  'usually': False,
#  'feeling': False,
#  'run': False,
#  'directed': False,
#  'child': False,
#  'roles': False,
#  'bring': False,
#  'major': False,
#  'talent': False,
#  'james': False,
#  'hour': False,
#  'late': False,
#  'silly': False,
#  'released': False,
#  'flick': False,
#  'says': False,
#  'how': False,
#  'genre': False,
#  'starts': False,
#  'exactly': True,
#  'killer': False,
#  'opening': False,
#  'hit': False,
#  'gore': False,
#  'view': False,
#  'lets': False,
#  'possible': False,
#  'dance': False,
#  'interest': False,
#  'cool': False,
#  'rock': False,
#  'ok': False,
#  'usual': False,
#  'on': True,
#  'side': True,
#  'daughter': False,
#  'relationship': False,
#  'none': False,
#  'moment': False,
#  'body': False,
#  'brother': False,
#  'filmbr': False,
#  'anyway': False,
#  'british': False,
#  'across': False,
#  'kid': False,
#  'serious': False,
#  'including': False,
#  'husband': False,
#  'obvious': False,
#  'actual': False,
#  'apparently': False,
#  'whose': False,
#  'saying': False,
#  'fight': False,
#  'important': False,
#  'team': False,
#  'review': False,
#  'happy': False,
#  'words': False,
#  'knows': False,
#  'alone': False,
#  'seriously': False,
#  'stories': False,
#  'blood': False,
#  'hours': False,
#  'score': False,
#  'mystery': False,
#  'from': True,
#  'due': True,
#  'today': False,
#  'jokes': False,
#  'romantic': False,
#  'surprise': False,
#  'hilarious': False,
#  'directors': False,
#  'local': False,
#  'hand': False,
#  'easy': False,
#  'annoying': False,
#  'etc': False,
#  'simple': False,
#  'problems': False,
#  'strong': False,
#  'lots': False,
#  'animation': False,
#  'enjoyable': False,
#  'moviebr': False,
#  'rating': False,
#  'arent': False,
#  'cut': False,
#  'talk': False,
#  'mostly': False,
#  'falls': False,
#  'started': False,
#  'female': False,
#  '4': False,
#  'dull': False,
#  'order': True,
#  'feels': False,
#  'miss': False,
#  'living': False,
#  'taking': False,
#  'learn': False,
#  'clear': False,
#  'filmed': False,
#  'basically': False,
#  'beyond': False,
#  'havent': False,
#  'talking': False,
#  'cheap': False,
#  '5': False,
#  'wonder': False,
#  'documentary': False,
#  'subject': False,
#  'crime': False,
#  'typical': False,
#  'space': False,
#  'by': False,
#  'country': False,
#  'please': False,
#  'sequence': False,
#  'novel': False,
#  '80s': False,
#  'room': False,
#  'taken': False,
#  'whats': False,
#  'bunch': False,
#  'particular': False,
#  'message': False,
#  'level': False,
#  'supporting': False,
#  'king': False,
#  'finds': False,
#  'doubt': False,
#  'single': False,
#  'turned': True,
#  'wish': False,
#  'youve': False,
#  'suspense': False,
#  'call': False,
#  'voice': False,
#  'french': False,
#  'knew': False,
#  'decided': False,
#  'modern': False,
#  'sets': False,
#  'shots': False,
#  'meet': False,
#  'events': False,
#  'musical': False,
#  'footage': False,
#  'predictable': False,
#  'george': False,
#  'tells': False,
#  'viewing': True,
#  'entertainment': False,
#  'ends': False,
#  'crap': False,
#  'wait': False,
#  'parents': False,
#  'giving': False,
#  'an': True,
#  'mention': False,
#  'cinematography': False,
#  'truth': False,
#  'happened': True,
#  'thriller': False,
#  'power': False,
#  'island': False,
#  'sequences': False,
#  'songs': False,
#  'sad': False,
#  'whether': False,
#  'among': False,
#  'tom': False,
#  'buy': False,
#  'realistic': False,
#  'forget': True,
#  'comments': False,
#  'lame': False,
#  'four': False,
#  'hero': False,
#  'moving': False,
#  'surprised': False,
#  'within': False,
#  'needs': False,
#  'add': False,
#  'clearly': False,
#  'working': False,
#  'directing': False,
#  'sorry': False,
#  'attention': False,
#  'editing': False,
#  'change': False,
#  'soundtrack': False,
#  'fantastic': False,
#  'famous': False,
#  'running': False,
#  'sister': False,
#  'begins': False,
#  'figure': False,
#  'screenplay': False,
#  'premise': False,
#  'named': False,
#  'most': False,
#  'reviews': False,
#  'class': True,
#  'career': False,
#  'monster': False,
#  'ten': False,
#  'future': False,
#  'romance': True,
#  'rent': False,
#  'form': False,
#  'feature': False,
#  'episodes': False,
#  'expected': False,
#  'dr': False,
#  'certain': False,
#  'laughs': False,
#  'portrayed': False,
#  'opinion': False,
#  'nearly': False,
#  'strange': False,
#  'showing': False,
#  'hate': False,
#  'setting': False,
#  'gone': False,
#  'somewhat': False,
#  'easily': False,
#  'check': False,
#  'scifi': False,
#  'die': False,
#  'brought': False,
#  'missing': False,
#  'greatest': False,
#  'personal': False,
#  'near': False,
#  'deal': False,
#  'features': False,
#  'hot': False,
#  'scary': False,
#  'jack': False,
#  'shame': False,
#  'begin': False,
#  'powerful': False,
#  'theater': False,
#  'storyline': False,
#  'tried': False,
#  'towards': False,
#  'fall': False,
#  'worked': False,
#  'crazy': False,
#  'appears': False,
#  'richard': False,
#  'various': False,
#  'avoid': False,
#  'sequel': False,
#  'crew': False,
#  'comic': False,
#  'match': False,
#  'average': False,
#  'using': False,
#  'stand': False,
#  'atmosphere': False,
#  'deep': False,
#  'imdb': False,
#  'total': False,
#  'viewers': False,
#  'lady': False,
#  'believable': False,
#  'indeed': False,
#  'dialog': False,
#  'elements': False,
#  'light': False,
#  'theme': False,
#  'stay': False,
#  'ways': False,
#  'memorable': False,
#  'hardly': False,
#  'five': False,
#  'de': False,
#  'somehow': False,
#  'middle': True,
#  'water': False,
#  'effort': False,
#  'means': False,
#  'writer': False,
#  'boys': False,
#  'sit': False,
#  'weak': False,
#  'disney': False,
#  'credits': False,
#  'caught': False,
#  'oscar': False,
#  'difficult': False,
#  'plain': False,
#  'similar': False,
#  'effect': False,
#  'hands': False,
#  'business': False,
#  'fast': False,
#  'her': False,
#  'japanese': False,
#  'quickly': False,
#  'mentioned': True,
#  'points': False,
#  'killing': False,
#  'these': False,
#  'rich': False,
#  'hear': False,
#  'follow': False,
#  'open': False,
#  'following': False,
#  'okay': False,
#  'peter': False,
#  'laughing': False,
#  'who': True,
#  'reasons': False,
#  'earlier': False,
#  'girlfriend': False,
#  'note': False,
#  'married': False,
#  'possibly': False,
#  'acted': False,
#  'paul': False,
#  'fails': False,
#  'straight': False,
#  'very': False,
#  'kept': False,
#  'list': False,
#  'general': False,
#  'leads': False,
#  'cute': False,
#  'meets': False,
#  'eye': False,
#  'whatever': False,
#  'filmmakers': False,
#  'audiences': True,
#  'imagine': False,
#  'secret': False,
#  'needed': False,
#  'question': False,
#  'release': False,
#  'bored': False,
#  'hold': False,
#  'leaves': False,
#  'material': False,
#  'immediately': False,
#  'dramatic': False,
#  'air': False,
#  'realize': False,
#  'success': False,
#  'previous': False,
#  'talented': False,
#  'minute': False,
#  'season': False,
#  'twist': False,
#  'members': False,
#  'otherwise': False,
#  'forward': False,
#  'b': False,
#  'company': False,
#  'leading': False,
#  'stage': False,
#  'became': False,
#  'earth': False,
#  'cause': False,
#  'plus': False,
#  'alien': False,
#  'eventually': False,
#  'died': False,
#  'write': False,
#  'do': False,
#  'unless': False,
#  'masterpiece': False,
#  'battle': False,
#  'period': False,
#  'whos': False,
#  'front': False,
#  'society': False,
#  'wasted': False,
#  'older': False,
#  '20': False,
#  'box': False,
#  'poorly': False,
#  'surprisingly': False,
#  'male': False,
#  'situation': False,
#  'ideas': False,
#  'decides': False,
#  'brings': False,
#  'changed': False,
#  'nature': False,
#  'doctor': False,
#  'office': False,
#  'slightly': False,
#  'awesome': False,
#  'superb': False,
#  'dumb': False,
#  'neither': False,
#  'apart': False,
#  'expecting': False,
#  'or': True,
#  'william': False,
#  'america': False,
#  'admit': False,
#  'result': False,
#  'situations': False,
#  'york': False,
#  'project': False,
#  'attempts': False,
#  'appear': False,
#  'weird': False,
#  'created': False,
#  'western': False,
#  'free': False,
#  'fairly': False,
#  'copy': False,
#  'sexual': False,
#  'move': False,
#  '15': False,
#  'thank': False,
#  'return': False,
#  'literally': False,
#  'remake': False,
#  'jim': False,
#  'considered': False,
#  'follows': False,
#  'zombie': False,
#  'band': False,
#  'tale': False,
#  'development': False,
#  'utterly': False,
#  'amount': False,
#  'uses': False,
#  'impossible': False,
#  'lovely': False,
#  'violent': False,
#  'deserves': False,
#  'basic': False,
#  'present': False,
#  'bought': False,
#  'ghost': False,
#  'perfectly': False,
#  'unlike': False,
#  'italian': False,
#  'public': False,
#  'ended': False,
#  'yeah': False,
#  'interested': False,
#  'photography': False,
#  'break': False,
#  'timebr': False,
#  'third': False,
#  'language': False,
#  'compared': False,
#  'pure': False,
#  'incredibly': False,
#  'sadly': False,
#  'animated': False,
#  'recently': False,
#  'solid': False,
#  'fighting': False,
#  'decide': False,
#  'appearance': False,
#  'plenty': False,
#  'former': False,
#  'honestly': False,
#  'cop': False,
#  'agree': False,
#  'starring': False,
#  'waiting': False,
#  'casting': False,
#  'mark': False,
#  'themes': False,
#  'clever': False,
#  'visual': False,
#  'here': False,
#  'meant': False,
#  'pay': False,
#  'suddenly': False,
#  'terrific': False,
#  'trip': False,
#  'manages': False,
#  'issues': False,
#  'gun': False,
#  'create': False,
#  'beauty': False,
#  'producers': False,
#  'bill': False,
#  'accent': False,
#  'pieces': False,
#  'badly': False,
#  'respect': False,
#  'spent': False,
#  'because': False,
#  'depth': False,
#  'political': False,
#  ...}

# %%
## Applying the function to all the reviews.
feature_set = [(search_features(doc), sentiment) for (doc, sentiment) in docs]

# %%
len(feature_set)
# Out:
# 3000

# %%
feature_set[12]
# Out:
# ({'i': False,
#   'br': True,
#   'the': True,
#   'movie': True,
#   'film': True,
#   'one': True,
#   'like': True,
#   'this': True,
#   'good': True,
#   'even': True,
#   'would': True,
#   'it': True,
#   'see': True,
#   'story': False,
#   'time': False,
#   'really': True,
#   'much': False,
#   'well': False,
#   'get': False,
#   'bad': False,
#   'also': False,
#   'first': True,
#   'people': False,
#   'great': False,
#   'dont': False,
#   'movies': False,
#   'way': False,
#   'made': True,
#   'films': False,
#   'make': False,
#   'characters': False,
#   'could': False,
#   'and': True,
#   'think': False,
#   'watch': False,
#   'but': True,
#   'many': True,
#   'its': False,
#   'little': False,
#   'plot': False,
#   'never': False,
#   'two': False,
#   'character': False,
#   'seen': False,
#   'a': True,
#   'know': True,
#   'acting': True,
#   'in': True,
#   'love': False,
#   'life': False,
#   'if': True,
#   'best': False,
#   'ever': False,
#   'show': False,
#   'better': False,
#   'say': False,
#   'still': False,
#   'scene': True,
#   'man': False,
#   'there': False,
#   'scenes': True,
#   'go': True,
#   'something': True,
#   'end': False,
#   'real': False,
#   'im': True,
#   'watching': False,
#   'doesnt': False,
#   'back': False,
#   'actors': False,
#   'funny': False,
#   'new': False,
#   'he': True,
#   'thing': False,
#   'though': False,
#   'years': False,
#   'didnt': False,
#   'going': False,
#   'find': True,
#   'look': False,
#   'work': True,
#   'makes': True,
#   'actually': True,
#   'another': False,
#   'want': False,
#   'us': False,
#   'lot': False,
#   'part': False,
#   'old': False,
#   'every': False,
#   'nothing': False,
#   'cant': False,
#   'director': False,
#   'got': True,
#   'quite': False,
#   'pretty': True,
#   'things': True,
#   'around': False,
#   'enough': False,
#   'young': False,
#   'however': False,
#   'world': False,
#   'cast': False,
#   'big': True,
#   'must': False,
#   'thats': False,
#   'seems': False,
#   'as': True,
#   'may': False,
#   'long': True,
#   'fact': False,
#   'give': False,
#   'come': False,
#   'take': True,
#   'gets': True,
#   'without': False,
#   'least': False,
#   'whole': True,
#   'almost': False,
#   'horror': False,
#   'always': False,
#   'ive': False,
#   'saw': True,
#   'thought': False,
#   'original': False,
#   'might': False,
#   'you': True,
#   'since': False,
#   'isnt': False,
#   'right': True,
#   'anything': False,
#   'interesting': False,
#   'script': False,
#   'times': False,
#   'feel': False,
#   'comedy': False,
#   'probably': False,
#   'role': False,
#   'what': True,
#   'done': False,
#   'point': False,
#   'theres': False,
#   'family': False,
#   'minutes': True,
#   'yet': False,
#   'anyone': False,
#   'played': True,
#   'performance': False,
#   'they': True,
#   'although': False,
#   'bit': False,
#   'series': False,
#   'far': False,
#   'action': False,
#   'last': False,
#   'music': False,
#   'away': False,
#   'comes': False,
#   'rather': False,
#   'guy': False,
#   'so': True,
#   'not': True,
#   'tv': False,
#   'sure': False,
#   'kind': False,
#   'making': True,
#   'woman': False,
#   'everything': True,
#   'three': True,
#   'hard': False,
#   'worst': False,
#   'girl': False,
#   'fun': False,
#   'book': False,
#   'takes': False,
#   'she': False,
#   'hes': False,
#   'when': True,
#   'true': True,
#   'course': False,
#   'watched': False,
#   'especially': False,
#   'believe': False,
#   'found': False,
#   'goes': True,
#   'money': False,
#   'american': False,
#   'day': False,
#   'wasnt': False,
#   'different': False,
#   'main': False,
#   'shows': False,
#   'worth': True,
#   'trying': False,
#   'audience': False,
#   'idea': False,
#   'looks': False,
#   'screen': True,
#   'effects': False,
#   'john': False,
#   'beautiful': False,
#   'dvd': False,
#   'put': False,
#   'ending': False,
#   'everyone': False,
#   'maybe': True,
#   'simply': False,
#   'set': True,
#   'my': False,
#   'all': True,
#   'read': False,
#   'reason': True,
#   'seem': False,
#   'left': False,
#   'looking': False,
#   'excellent': False,
#   '10': False,
#   'place': False,
#   'night': False,
#   'together': True,
#   'completely': False,
#   'sense': False,
#   'plays': False,
#   'war': False,
#   'actor': False,
#   'for': True,
#   'special': False,
#   'instead': False,
#   'men': False,
#   'help': False,
#   'play': True,
#   'we': True,
#   'someone': False,
#   'job': False,
#   'short': False,
#   'nice': True,
#   'poor': False,
#   'seeing': False,
#   'fan': True,
#   'given': False,
#   'no': True,
#   'tell': False,
#   '2': False,
#   'along': True,
#   'shot': False,
#   'home': False,
#   'star': False,
#   'mind': False,
#   'said': False,
#   'use': True,
#   'used': False,
#   'line': False,
#   'else': False,
#   'second': False,
#   'performances': False,
#   'later': False,
#   'need': False,
#   'youre': False,
#   'father': False,
#   'version': False,
#   'house': False,
#   'rest': False,
#   'kids': False,
#   'high': False,
#   'wonderful': False,
#   'piece': False,
#   'black': False,
#   'recommend': False,
#   'try': False,
#   'human': False,
#   'year': False,
#   'less': False,
#   'absolutely': False,
#   'next': False,
#   'stupid': False,
#   'hollywood': False,
#   'dead': False,
#   'enjoy': False,
#   'classic': False,
#   'that': True,
#   'playing': False,
#   'either': False,
#   'mean': False,
#   'boring': False,
#   'remember': False,
#   'half': False,
#   'at': False,
#   'definitely': False,
#   'let': False,
#   'of': True,
#   'wife': False,
#   'production': False,
#   'title': False,
#   'terrible': False,
#   'women': False,
#   'small': False,
#   'understand': False,
#   'truly': False,
#   'awful': False,
#   'based': False,
#   'came': False,
#   'video': False,
#   'others': False,
#   'couple': False,
#   'death': False,
#   'totally': False,
#   'keep': False,
#   'mother': False,
#   'friends': False,
#   'loved': False,
#   'moments': False,
#   'case': False,
#   'game': True,
#   'fans': False,
#   'couldnt': False,
#   'lost': False,
#   'youll': False,
#   'stars': False,
#   'wrong': False,
#   'finally': False,
#   'evil': True,
#   'after': False,
#   'several': False,
#   'camera': False,
#   'start': False,
#   'school': False,
#   'top': False,
#   'sex': False,
#   'worse': False,
#   'humor': False,
#   'getting': False,
#   'often': False,
#   'name': False,
#   'perfect': False,
#   'face': False,
#   'person': True,
#   'liked': False,
#   'shes': False,
#   'budget': False,
#   'already': False,
#   'full': False,
#   'girls': False,
#   'yes': True,
#   'to': True,
#   'friend': False,
#   'dialogue': False,
#   'episode': False,
#   '3': False,
#   'despite': False,
#   'lines': False,
#   'wants': False,
#   'overall': False,
#   'written': False,
#   'while': False,
#   'some': True,
#   'beginning': False,
#   'gives': False,
#   'entire': False,
#   'mr': False,
#   'direction': False,
#   'waste': False,
#   'sort': False,
#   'becomes': False,
#   'favorite': False,
#   'perhaps': False,
#   'id': False,
#   'felt': False,
#   'dark': False,
#   'supposed': False,
#   'certainly': False,
#   'called': True,
#   'laugh': True,
#   'turn': False,
#   'picture': False,
#   'become': False,
#   'drama': False,
#   'early': False,
#   'town': False,
#   'seemed': False,
#   'children': False,
#   'then': True,
#   'quality': False,
#   'hope': False,
#   'guys': False,
#   'wanted': False,
#   'matter': False,
#   'sound': False,
#   'final': False,
#   'head': False,
#   'oh': False,
#   '\x96': False,
#   'cinema': False,
#   'throughout': False,
#   'soon': False,
#   'gave': False,
#   'why': False,
#   'able': False,
#   'his': True,
#   'parts': False,
#   'history': False,
#   'stuff': False,
#   'entertaining': False,
#   'problem': False,
#   'care': False,
#   'fine': False,
#   'now': False,
#   'number': False,
#   'lack': False,
#   'eyes': False,
#   'days': False,
#   'style': False,
#   'lives': False,
#   'live': False,
#   'past': False,
#   'went': False,
#   'viewer': False,
#   'extremely': False,
#   'white': False,
#   'theyre': False,
#   'ill': False,
#   'brilliant': False,
#   'type': False,
#   'wont': False,
#   'writing': False,
#   'enjoyed': True,
#   'murder': False,
#   'low': False,
#   'behind': False,
#   'ones': False,
#   'god': False,
#   'is': True,
#   'actress': False,
#   'robert': False,
#   'itbr': False,
#   'unfortunately': False,
#   'art': False,
#   'coming': False,
#   'save': False,
#   'attempt': False,
#   'lead': False,
#   'violence': False,
#   'just': True,
#   'expect': False,
#   'experience': True,
#   'boy': False,
#   'turns': False,
#   'tries': False,
#   'hell': False,
#   'thinking': False,
#   'leave': False,
#   'amazing': False,
#   'police': False,
#   'obviously': False,
#   'son': False,
#   'word': False,
#   'ridiculous': False,
#   'horrible': False,
#   'example': False,
#   'group': False,
#   'city': False,
#   'works': False,
#   'told': False,
#   'sometimes': False,
#   'michael': False,
#   'slow': False,
#   'happens': False,
#   '1': False,
#   'david': False,
#   'decent': False,
#   'involved': False,
#   'car': False,
#   'heart': False,
#   'wouldnt': False,
#   'stop': False,
#   'happen': False,
#   'television': False,
#   'shown': False,
#   'complete': False,
#   'song': False,
#   'except': False,
#   'known': False,
#   'with': True,
#   'took': False,
#   'ago': True,
#   'guess': False,
#   'age': False,
#   'act': False,
#   'disappointed': True,
#   'chance': False,
#   'heard': False,
#   'particularly': False,
#   'looked': True,
#   'close': False,
#   'highly': False,
#   'english': False,
#   'reality': False,
#   'upon': False,
#   'killed': False,
#   'kill': False,
#   'huge': False,
#   'usually': False,
#   'feeling': False,
#   'run': False,
#   'directed': False,
#   'child': False,
#   'roles': False,
#   'bring': False,
#   'major': False,
#   'talent': False,
#   'james': False,
#   'hour': False,
#   'late': False,
#   'silly': False,
#   'released': False,
#   'flick': False,
#   'says': False,
#   'how': True,
#   'genre': False,
#   'starts': False,
#   'exactly': False,
#   'killer': False,
#   'opening': False,
#   'hit': False,
#   'gore': False,
#   'view': False,
#   'lets': False,
#   'possible': False,
#   'dance': False,
#   'interest': False,
#   'cool': False,
#   'rock': False,
#   'ok': False,
#   'usual': False,
#   'on': True,
#   'side': False,
#   'daughter': False,
#   'relationship': False,
#   'none': False,
#   'moment': False,
#   'body': False,
#   'brother': False,
#   'filmbr': False,
#   'anyway': False,
#   'british': False,
#   'across': False,
#   'kid': False,
#   'serious': False,
#   'including': False,
#   'husband': False,
#   'obvious': False,
#   'actual': False,
#   'apparently': True,
#   'whose': False,
#   'saying': False,
#   'fight': False,
#   'important': False,
#   'team': False,
#   'review': False,
#   'happy': False,
#   'words': False,
#   'knows': False,
#   'alone': False,
#   'seriously': False,
#   'stories': False,
#   'blood': False,
#   'hours': False,
#   'score': False,
#   'mystery': False,
#   'from': True,
#   'due': False,
#   'today': False,
#   'jokes': False,
#   'romantic': False,
#   'surprise': False,
#   'hilarious': False,
#   'directors': False,
#   'local': False,
#   'hand': False,
#   'easy': False,
#   'annoying': True,
#   'etc': False,
#   'simple': False,
#   'problems': False,
#   'strong': False,
#   'lots': False,
#   'animation': False,
#   'enjoyable': False,
#   'moviebr': False,
#   'rating': False,
#   'arent': False,
#   'cut': False,
#   'talk': False,
#   'mostly': False,
#   'falls': False,
#   'started': True,
#   'female': False,
#   '4': False,
#   'dull': False,
#   'order': False,
#   'feels': False,
#   'miss': False,
#   'living': False,
#   'taking': False,
#   'learn': False,
#   'clear': False,
#   'filmed': False,
#   'basically': False,
#   'beyond': True,
#   'havent': False,
#   'talking': False,
#   'cheap': False,
#   '5': False,
#   'wonder': False,
#   'documentary': False,
#   'subject': False,
#   'crime': False,
#   'typical': False,
#   'space': False,
#   'by': True,
#   'country': False,
#   'please': False,
#   'sequence': False,
#   'novel': False,
#   '80s': False,
#   'room': False,
#   'taken': False,
#   'whats': False,
#   'bunch': False,
#   'particular': False,
#   'message': False,
#   'level': False,
#   'supporting': False,
#   'king': False,
#   'finds': False,
#   'doubt': False,
#   'single': False,
#   'turned': False,
#   'wish': False,
#   'youve': False,
#   'suspense': False,
#   'call': False,
#   'voice': False,
#   'french': False,
#   'knew': False,
#   'decided': False,
#   'modern': False,
#   'sets': False,
#   'shots': False,
#   'meet': False,
#   'events': False,
#   'musical': False,
#   'footage': False,
#   'predictable': False,
#   'george': False,
#   'tells': False,
#   'viewing': False,
#   'entertainment': False,
#   'ends': False,
#   'crap': False,
#   'wait': False,
#   'parents': False,
#   'giving': False,
#   'an': True,
#   'mention': False,
#   'cinematography': False,
#   'truth': False,
#   'happened': False,
#   'thriller': False,
#   'power': False,
#   'island': True,
#   'sequences': False,
#   'songs': False,
#   'sad': False,
#   'whether': False,
#   'among': False,
#   'tom': False,
#   'buy': False,
#   'realistic': False,
#   'forget': False,
#   'comments': False,
#   'lame': False,
#   'four': False,
#   'hero': False,
#   'moving': False,
#   'surprised': False,
#   'within': False,
#   'needs': False,
#   'add': False,
#   'clearly': False,
#   'working': False,
#   'directing': False,
#   'sorry': False,
#   'attention': False,
#   'editing': False,
#   'change': False,
#   'soundtrack': False,
#   'fantastic': False,
#   'famous': False,
#   'running': False,
#   'sister': False,
#   'begins': False,
#   'figure': False,
#   'screenplay': False,
#   'premise': False,
#   'named': False,
#   'most': True,
#   'reviews': False,
#   'class': False,
#   'career': False,
#   'monster': False,
#   'ten': False,
#   'future': False,
#   'romance': False,
#   'rent': False,
#   'form': False,
#   'feature': False,
#   'episodes': False,
#   'expected': False,
#   'dr': False,
#   'certain': False,
#   'laughs': False,
#   'portrayed': False,
#   'opinion': False,
#   'nearly': False,
#   'strange': False,
#   'showing': False,
#   'hate': False,
#   'setting': False,
#   'gone': True,
#   'somewhat': False,
#   'easily': False,
#   'check': False,
#   'scifi': False,
#   'die': False,
#   'brought': False,
#   'missing': False,
#   'greatest': False,
#   'personal': False,
#   'near': False,
#   'deal': False,
#   'features': False,
#   'hot': False,
#   'scary': False,
#   'jack': False,
#   'shame': False,
#   'begin': False,
#   'powerful': False,
#   'theater': False,
#   'storyline': True,
#   'tried': False,
#   'towards': False,
#   'fall': False,
#   'worked': False,
#   'crazy': False,
#   'appears': False,
#   'richard': False,
#   'various': False,
#   'avoid': False,
#   'sequel': False,
#   'crew': False,
#   'comic': False,
#   'match': False,
#   'average': False,
#   'using': False,
#   'stand': False,
#   'atmosphere': False,
#   'deep': False,
#   'imdb': False,
#   'total': False,
#   'viewers': False,
#   'lady': False,
#   'believable': False,
#   'indeed': False,
#   'dialog': False,
#   'elements': False,
#   'light': False,
#   'theme': False,
#   'stay': True,
#   'ways': False,
#   'memorable': False,
#   'hardly': False,
#   'five': False,
#   'de': False,
#   'somehow': False,
#   'middle': False,
#   'water': False,
#   'effort': False,
#   'means': False,
#   'writer': False,
#   'boys': False,
#   'sit': False,
#   'weak': False,
#   'disney': False,
#   'credits': False,
#   'caught': False,
#   'oscar': False,
#   'difficult': False,
#   'plain': False,
#   'similar': False,
#   'effect': False,
#   'hands': False,
#   'business': False,
#   'fast': False,
#   'her': False,
#   'japanese': False,
#   'quickly': False,
#   'mentioned': False,
#   'points': False,
#   'killing': True,
#   'these': False,
#   'rich': True,
#   'hear': False,
#   'follow': False,
#   'open': False,
#   'following': False,
#   'okay': False,
#   'peter': False,
#   'laughing': False,
#   'who': True,
#   'reasons': False,
#   'earlier': False,
#   'girlfriend': False,
#   'note': False,
#   'married': False,
#   'possibly': False,
#   'acted': False,
#   'paul': False,
#   'fails': False,
#   'straight': False,
#   'very': True,
#   'kept': False,
#   'list': False,
#   'general': False,
#   'leads': False,
#   'cute': False,
#   'meets': False,
#   'eye': False,
#   'whatever': False,
#   'filmmakers': False,
#   'audiences': False,
#   'imagine': False,
#   'secret': True,
#   'needed': False,
#   'question': False,
#   'release': False,
#   'bored': False,
#   'hold': False,
#   'leaves': False,
#   'material': False,
#   'immediately': False,
#   'dramatic': False,
#   'air': False,
#   'realize': False,
#   'success': False,
#   'previous': False,
#   'talented': False,
#   'minute': False,
#   'season': False,
#   'twist': False,
#   'members': False,
#   'otherwise': False,
#   'forward': False,
#   'b': False,
#   'company': False,
#   'leading': False,
#   'stage': False,
#   'became': False,
#   'earth': False,
#   'cause': False,
#   'plus': False,
#   'alien': False,
#   'eventually': False,
#   'died': False,
#   'write': False,
#   'do': True,
#   'unless': False,
#   'masterpiece': False,
#   'battle': False,
#   'period': False,
#   'whos': False,
#   'front': False,
#   'society': False,
#   'wasted': False,
#   'older': False,
#   '20': False,
#   'box': False,
#   'poorly': False,
#   'surprisingly': False,
#   'male': False,
#   'situation': False,
#   'ideas': False,
#   'decides': False,
#   'brings': False,
#   'changed': False,
#   'nature': False,
#   'doctor': False,
#   'office': False,
#   'slightly': False,
#   'awesome': False,
#   'superb': False,
#   'dumb': False,
#   'neither': False,
#   'apart': False,
#   'expecting': False,
#   'or': True,
#   'william': False,
#   'america': False,
#   'admit': False,
#   'result': False,
#   'situations': False,
#   'york': False,
#   'project': False,
#   'attempts': False,
#   'appear': False,
#   'weird': False,
#   'created': False,
#   'western': False,
#   'free': False,
#   'fairly': False,
#   'copy': False,
#   'sexual': False,
#   'move': False,
#   '15': False,
#   'thank': False,
#   'return': False,
#   'literally': False,
#   'remake': False,
#   'jim': False,
#   'considered': False,
#   'follows': False,
#   'zombie': False,
#   'band': False,
#   'tale': True,
#   'development': False,
#   'utterly': False,
#   'amount': False,
#   'uses': False,
#   'impossible': False,
#   'lovely': False,
#   'violent': False,
#   'deserves': False,
#   'basic': False,
#   'present': False,
#   'bought': True,
#   'ghost': False,
#   'perfectly': False,
#   'unlike': False,
#   'italian': False,
#   'public': False,
#   'ended': False,
#   'yeah': False,
#   'interested': False,
#   'photography': False,
#   'break': False,
#   'timebr': False,
#   'third': False,
#   'language': False,
#   'compared': False,
#   'pure': False,
#   'incredibly': False,
#   'sadly': False,
#   'animated': False,
#   'recently': False,
#   'solid': False,
#   'fighting': True,
#   'decide': False,
#   'appearance': False,
#   'plenty': False,
#   'former': False,
#   'honestly': False,
#   'cop': False,
#   'agree': False,
#   'starring': False,
#   'waiting': False,
#   'casting': False,
#   'mark': False,
#   'themes': False,
#   'clever': False,
#   'visual': False,
#   'here': True,
#   'meant': False,
#   'pay': False,
#   'suddenly': False,
#   'terrific': False,
#   'trip': False,
#   'manages': False,
#   'issues': False,
#   'gun': False,
#   'create': False,
#   'beauty': False,
#   'producers': False,
#   'bill': False,
#   'accent': False,
#   'pieces': False,
#   'badly': False,
#   'respect': False,
#   'spent': False,
#   'because': False,
#   'depth': False,
#   'political': False,
#   ...},
#  'neg')

# %%
training_set = feature_set[:1500]
testing_set = feature_set[1500:]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
print("classifier's accuracy is: {}".format(nltk.classify.accuracy(classifier, testing_set))*100)
# Out:
# classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.8146666666666667classifier's accuracy is: 0.814666666666 ...

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                    waste = True              neg : pos    =     22.3 : 1.0
#                   wasted = True              neg : pos    =     12.3 : 1.0
#                     seat = True              pos : neg    =     11.8 : 1.0
#                laughable = True              neg : pos    =     11.5 : 1.0
#                 stunning = True              pos : neg    =     11.2 : 1.0
#                    awful = True              neg : pos    =      9.9 : 1.0
#                 horrible = True              neg : pos    =      9.6 : 1.0
#              brilliantly = True              pos : neg    =      9.2 : 1.0
#              emotionally = True              pos : neg    =      9.2 : 1.0
#                 identity = True              pos : neg    =      9.2 : 1.0

# %% [markdown]
# # Saving the model

# %%
import pickle
save_classifier = open("naive_bayes_model.pkl","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %% [markdown]
# # Loading the model

# %%
classifier_f = open('naive_bayes_model.pkl','rb')
classifier = pickle.load(classifier_f)
#classifier_f.close()

# %% [markdown]
# # Testing the model

# %%
#custom_review = 'I hated the restaurant. it was a disaster eating there, Poor service, arrogant waiters'

custom_review = '''I had a great time eating delicious food at your restaurant. 
                the waiters and waitresses were committed to great service and were very friendly'''

# %%
custom_review_tokens = word_tokenize(custom_review)
custom_review_set = search_features(custom_review_tokens)
print(classifier.classify(custom_review_set))
# Out:
# pos

# %%
prob_result = (classifier.prob_classify(custom_review_set))

print(prob_result.max())
print(prob_result.prob('pos'))
print(prob_result.prob('neg'))
# Out:
# pos
# 0.9310158275632736
# 0.06898417243672267

# %%
classifier_f.close()
